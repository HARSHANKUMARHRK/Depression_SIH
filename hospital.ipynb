# %%
import pandas as pd

# %%
df=pd.read_csv("HospitalsInIndia.csv")
df
# Out:
#       Unnamed: 0                                       Hospital        State  \
# 0              0                                   A A Hospital    Tamilnadu
# 1              1                                   A C Hospital    Tamilnadu
# 2              2          A-Care Orthopaedic & General Hospital  Maharashtra
# 3              3                         A-One Hospital Pvt Ltd        Delhi
# 4              4                              A.B.Eye Institute        Bihar
# ...          ...                                            ...          ...
# 1343        1343                     Dr. Mahesh Rathod Hospital      Gujarat
# 1344        1344                   Dr. Malathi Manipal Hospital    Karnataka
# 1345        1345             Dr. Manish Patankars Nath Hospital  Maharashtra
# 1346        1346       Dr. Manohara Sai Gowda Memorial Hospital    Karnataka
# 1347        1347  Dr. Mehta'S Multispeciality Hospital Pvt Ltd.    Tamilnadu
#
# ...

# %%
state=input("Enter state")

city=input("Enter city")
# Out:
# Enter state tamilnadu
# Enter city hosur

# %%
inp=state[0].upper()+state[1::]

# %%
# c=0
# for i in df["State"]:
#     if(inp in i):
#         c+=1
#         hospital = df.loc[df["State"]=="Tamilnadu", 'Hospital'].values[]
# print("total number of records found",hospital)

# %%
subset = df.loc[df['State'].isin(['{}'.format(inp)])]
hospital = subset.loc[:, 'Hospital']
loc_address=subset.loc[:,'LocalAddress']
data=pd.DataFrame(loc_address)
dq=pd.DataFrame(hospital)
result = pd.concat([data, dq], axis=0)
data
# Out:
#                                            LocalAddress
# 0                         Denkani Kottai Road Mathigiri
# 1     No-8, 3Rd Main Road, United India Nagar, Ayana...
# 5                                     201,2Nd Agraharam
# 6     No. 106, R.K. Mutt Road. Mylapore, Chennai, Ta...
# 7                    34, Kpn Colony 3Rd Street, Tirupur
# ...                                                 ...
# 1329                       #1159, K.P. Road, Nagerkoil.
# 1331                        #93, Power House Road,Erode
# 1339  N.H. Road # 47, 1/4C,1/4D,1/4E Perumalpuramper...
# 1341                  606/A, Mettur Main Road, Bhavani,
# 1347  2 (E), Mc. Nicholas Road, Chennai, Opposite To...
#
# [179 rows x 1 columns]

# %%
dq
# Out:
#                                                Hospital
# 0                                          A A Hospital
# 1                                          A C Hospital
# 5                                         A.C. Hospital
# 6     A.G. Eye Care Hospitals (U Nit Of Dr. A.G. Eye...
# 7                                         A.G. Hospital
# ...                                                 ...
# 1329                     Dr. Jeyasekharan Medical Trust
# 1331                       Dr. K.M. Nallaswamy Hospital
# 1339  Dr. Kumaraswami Health Centre ( A Unit Of Indi...
# 1341                Dr. Loganathan Orthopaedic Hospital
# 1347      Dr. Mehta'S Multispeciality Hospital Pvt Ltd.
#
# [179 rows x 1 columns]
